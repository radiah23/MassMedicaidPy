# %%
from MassMedicaidPy.Household_Information import code_household
from MassMedicaidPy.Plan_Information import code_plan
from MassMedicaidPy.Condition_Information import code_condition

# %%
#Person Class
person = code_household.Person("Female", "US Citizen", "2004-05-05", "MA")
print(f"Gender : {person.gender}")
print(f"Citizenship : {person.citizenship}") 
print(f"")
# Out:
# Gender : Female
# Citizenship : US Citizen

# %%
#Creating an individual data
individual_data = {
    "gender": "Female",
    "citizenship": "US Citizen",
    "birthdate": "2002-06-10",
    "state": "Calfornia",
    "disability_status": False,
    "pregnancy_status": False,
    "is_primary_caretaker": False
}
individual_data
# Out:
# {'gender': 'Female',
#  'citizenship': 'US Citizen',
#  'birthdate': '2002-06-10',
#  'state': 'Calfornia',
#  'disability_status': False,
#  'pregnancy_status': False,
#  'is_primary_caretaker': False}
